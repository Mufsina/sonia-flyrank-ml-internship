# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mufsina/sonia-flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane: Ranking / Scoring
#
# I chose the Ranking / Scoring lane because editors usually have many pages to manage but limited time. Instead of checking every page one by one, a ranked list can help them decide which pages should be updated first. I think this is a practical problem, and building a ranking model could help make that decision easier.

# %%
lane = "Ranking / Scoring"
print("Selected Lane:", lane)
# Out:
# Selected Lane: Ranking / Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision:** Which content pages should be refreshed first?
#
# **Who acts?** SEO editors or content managers.
#
# **Action:** They review the pages with the highest priority and decide which ones to update.
#
# **Cost of a wrong recommendation:** If a page that does not need attention is ranked too high, editors may waste time. If an important declining page is missed, it may continue to lose traffic before anyone notices.
#
# **Why ML?** A simple rule can be a good starting point, but it may not use all the available information. If different signals work together in useful ways, a ranking model may provide better decision support than a single rule.

# %%
decision = "Choose which pages to refresh first"
actor = "SEO Editor"
action = "Update the highest-priority pages"

print("Decision:", decision)
print("Actor:", actor)
print("Action:", action)
# Out:
# Decision: Choose which pages to refresh first
# Actor: SEO Editor
# Action: Update the highest-priority pages

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset contains **30,000 content items** from **32 different clients**. The trend distribution shows that **16,262 pages are marked as "down"**, while **5,962 are "stable"**. This suggests that many pages may need attention, making the ranking problem worth exploring during the project.

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()


filename = list(uploaded.keys())[0]

df = pd.read_csv(filename)

print("Dataset loaded successfully!\n")

print(f"Rows: {len(df):,}")
print(f"Columns: {len(df.columns)}")
print(f"Unique clients: {df['client_id'].nunique()}")

print("\nTrend direction counts:")
print(df["trend_direction"].value_counts())
# Out:
#      <input type="file" id="files-73bf3668-3732-4cee-a368-4733f9871ff9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73bf3668-3732-4cee-a368-4733f9871ff9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project is meant to support decisions, not replace them. The results can help editors decide which pages may deserve attention, but they cannot guarantee that updating a page will improve its performance.
#
# I will not use **trend_direction** or **trend_pct** as input features because they are related to the outcome and could cause target leakage.
#
# The findings from this project will be based on the available data. They can show observed patterns and support decisions, but they cannot prove cause and effect or predict how Google will rank pages in the future.

# %%
excluded_features = ["trend_direction", "trend_pct"]

print("Features excluded to avoid target leakage:")
print(excluded_features)
# Out:
# Features excluded to avoid target leakage:
# ['trend_direction', 'trend_pct']

# %% [markdown]
# - [x] I completed every markdown and code section.
# - [x] The notebook runs from top to bottom without errors.
# - [x] No client names, URLs, or private queries are included.
# - [x] My claims use careful words such as observed, measured, directional, and decision-support.
# - [x] I will commit the notebook under `work/notebooks/` before submitting my repository URL.
