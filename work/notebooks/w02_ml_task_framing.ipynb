# %% [markdown]
# <a href="https://colab.research.google.com/github/Mufsina/sonia-flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Mufsina/sonia-flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My lane as an ML task
#
# I chose a ranking/scoring task because the goal is to decide which content pages should be refreshed first. Instead of giving a yes or no answer, the model ranks pages by priority. This helps editors spend their time on the pages that are likely to benefit the most from an update.

# %%
ml_task = "Ranking / Scoring"
print("ML Task:", ml_task)
# Out:
# ML Task: Ranking / Scoring

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or proxy
#
# The output is a refresh priority score for each content page. In this notebook, I use a proxy because the starter dataset is a historical snapshot. I do not use `trend_direction` or `trend_pct` as input features because they describe the outcome and could cause target leakage. The model should learn from the other historical features instead.

# %%
import pandas as pd

df = pd.read_csv("/content/sonia-flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

leakage_columns = ["trend_direction", "trend_pct"]

print("Columns excluded because of target leakage:")
print(leakage_columns)
# Out:
# Columns excluded because of target leakage:
# ['trend_direction', 'trend_pct']

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success metric
#
# I will use Precision@10 as the main metric. Since the goal is to recommend only the highest-priority pages, this metric shows how useful the top recommendations are.

# %%
metric = "Precision@10"

print("Evaluation Metric:", metric)
# Out:
# Evaluation Metric: Precision@10

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# ## The unit of analysis
#
# One row in the dataset represents one content page. Each row contains historical search and engagement information for that page over the previous 90 days.

# %%
import pandas as pd

df = pd.read_csv("/content/sonia-flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.head()
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Why ML beats a fixed rule here
#
# A simple rule cannot consider all the information at the same time. Search performance depends on many factors, and those factors can affect each other. Machine learning can look at several signals together and give a better ranking. The output is meant to support decisions, not replace them.

# %%
import pandas as pd

df = pd.read_csv("/content/sonia-flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

print("Dataset shape:", df.shape)
print("Number of columns:", len(df.columns))

print("\nExample columns:")
print(df.columns[:10].tolist())
# Out:
# Dataset shape: (30000, 44)
# Number of columns: 44
#
# Example columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count']

# %% [markdown]
# - [x] Every section is completed.
# - [x] The notebook runs from top to bottom.
# - [x] No client names, URLs, or private data are included.
# - [x] My answers use careful, decision-support language.
# - [x] The notebook will be committed to `work/notebooks/`.
